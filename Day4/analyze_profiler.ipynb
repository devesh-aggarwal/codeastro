# %% [markdown]
# # Code Profiling
#
# Code profiling is the process of dynamically analyzing the performance of your code or software, focusing on aspects like runtime, memory allocation, and function execution frequency. Its primary goal is to identify performance bottlenecks, excessive resource consumption, and areas that take too long to execute, enabling developers to optimize their code for better efficiency and speed.
#
# In this lesson, we only talk about runtime profiling. Use this as an inspiration to check out memory profiling (modules like [`memory_profiler`](https://pypi.org/project/memory-profiler/) and [`tracemalloc`](https://docs.python.org/3/library/tracemalloc.html)).

# %% [markdown]
# ## cProfile (our friendly neighborhood profiler)
#
# At its core, a runtime profiler is just a timer (like the `timeit` function). Under the hood, it inserts hooks into the Python interpreter that track when functions start and stop, so it can measure the exact time spent in each one. The result is a detailed performance breakdown of your script.
#
# Here we use a simple Python profiler called `cProfile`, which is built into the Python standard library. So, all of you already have it! `cProfile` gets its name from being the C-extension version of the older Python `profile` module.

# %% [markdown]
# # Running cProfile
#
# First, create a Python script that repeatedly calls the function or class you want to speed up a few hundred times atleast (this helps average out any variations in execution time due to different input parameters or simply makes sure the most time consuming functions are reflected as such in the output file). Then, run the following command from the command line:
#
# `python -m cProfile -o profiler_output.txt profile_orbitize.py`
#
# - The `-m cProfile` will attach the cProfile profiler to this script when it runs.
#
# - The `-o profiler_output.txt` will save its output to "profiler_output.txt" (otherwise it dumps the output stats into stdout).
#
# _Note on parallelization: Using parallelism will make the cprofiler output more confusing than necessary. We just want to know what takes the most time,
# summed up across multiple processes. Doing this on parallelized code, each process must save its own cProfile output and you
# need to combine the outputs afterwards (using `pstats.add()`)._

# %% [markdown]
# # Analyzing the cProfile output
#
# After you have run the `profile_orbitize.py` function with the cProfile package, we will use the `pstats` module (part of Python standard library) to read and analyze the output of the profiler (a binary file) and identify bottlenecks in the code. Reference: [pstats documentation](https://docs.python.org/3/library/profile.html)
#
# PS: If you are in Colaboratory, you will need to upload the output of the cProfile to Colaboratory!

# %%
import pstats

mystats = pstats.Stats("profiler_output.txt")

# %% [markdown]
# ### Finding the top 5 functions that took the longest time to run

# %% [markdown]
# The function below sorts the functions by which took the longest to run, and prints out only the stats of the top 5 functions that took longest to run. The columns below mean:
#   * "ncalls" - number of times this function was called
#   * "tottime" - the total execution time spent in this code NOT including calls to other functions
#   * "percall" - this first percall divides tottime by ncalls. The amount of time per call spent solely in this function.
#   * "cumtime" - the total execution time spent in this code INCLUDING calls to sub functions.
#   * "percall" - second percall divides cumtime by ncalls
#   * "filename:lineno(function)" - shows where the function is defined in the package; its file, line number, and name.

# %%
mystats.sort_stats("time").print_stats(5)
# Out:
# Wed Jun 24 15:22:56 2026    profiler_output.txt
#
#          22448399 function calls (22227393 primitive calls) in 190.889 seconds
#
#    Ordered by: internal time
#    List reduced from 10232 to 5 due to restriction <5>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#   184/183   72.694    0.395   72.700    0.397 {built-in method _imp.create_dynamic}
#      4866   24.556    0.005   24.621    0.005 /Users/bluez3303/Documents/GitHub/codeastro/.venv/lib/python3.13/site-packages/orbitize/kepler.py:199(_newton_solver_wrapper)
#      4866   23.260    0.005   68.091    0.014 /Users/bluez3303/Documents/GitHub/codeastro/.venv/lib/python3.13/site-packages/orbitize/kepler.py:48(calc_orbit)
#      4866    7.787    0.002    7.787    0.002 /Users/bluez3303/Documents/GitHub/codeastro/.venv/lib/python3.13/site-packages/orbitize/system.py:733(radec2seppa)
#      4866    6.078    0.001   31.904    0.007 /Users/bluez3303/Documents/GitHub/codeastro/.venv/lib/python3.13/site-packages/orbitize/kepler.py:143(_calc_ecc_anom)

# %% [markdown]
# ### Which functions to target?

# %% [markdown]
# Even in such a short script, python called millions of function! A lot of them are super quick and really not what we are after. Typically, we want to find the few functions that are bottlenecks in our code. For this, both `tottime` and `cumtime` are useful. Note: <u>cumtime > tottime always</u>
#
# A function with a high `tottime` means we should focus on speeding up this function. A function with only a high `cumtime` means we should see what this function is calling to improve runtime. For example, amongst the functions displayed above:
#   * `_newton_solver_wrapper()` is a function with a high tottime. We should look at the lines in that function to check out how to speed it up.
#   * `_calc_ecc_anom()` is a function with a low tottime but a very high `cumtime`. We should look at the functions it calls to figure out what takes up so much time.

# %% [markdown]
# ### Multiple Filters (Order Matters!)
#
# Generally, we want to put some filters on `print_stats`, because otherwise there will be so much printed out it is unmanageable.
#
# - For example, calling `sort_stats("time").print_stats(15,"numpy")` would pick the top 15 longest runtime functions, and then downselects those which have `numpy` name in them. That would give us less than 15 numpy functions.

# %%
mystats.sort_stats("time").print_stats(15, "numpy")
# Out:
# Wed Jun 24 15:22:56 2026    profiler_output.txt
#
#          22448399 function calls (22227393 primitive calls) in 190.889 seconds

# %% [markdown]
# - Whereas, the `print_stats("numpy", 15)` command first selects every function with `numpy` in the name and then picks the top 15 that took the most time to run.

# %%
mystats.sort_stats("time").print_stats("numpy", 15)
# Out:
# Wed Jun 24 15:22:56 2026    profiler_output.txt
#
#          22448399 function calls (22227393 primitive calls) in 190.889 seconds
#
#    Ordered by: internal time
#    List reduced from 10232 to 673 due to restriction <'numpy'>
#    List reduced from 673 to 15 due to restriction <15>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#     54487    0.687    0.000    0.687    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#     21928    0.590    0.000    0.590    0.000 {built-in method numpy.zeros}
#    142329    0.511    0.000    0.511    0.000 {built-in method numpy.array}
# 290456/290454    0.189    0.000    0.334    0.000 {method 'view' of 'numpy.ndarray' objects}
#     19467    0.171    0.000    0.219    0.000 /Users/bluez3303/Documents/GitHub/codeastro/.venv/lib/python3.13/site-packages/numpy/lib/_stride_tricks_impl.py:447(_broadcast_to)
#     14598    0.170    0.000    0.170    0.000 {built-in method numpy._core._multiarray_umath._place}
#      2433    0.140    0.000    0.237    0.000 /Users/bluez3303/Documents/GitHub/codeastro/.venv/lib/python3.13/site-packages/numpy/lib/_nanfunctions_impl.py:70(_replace_nan)
#     14661    0.127    0.000    0.127    0.000 {built-in method numpy.arange}
#      9880    0.109    0.000    0.109    0.000 {method 'astype' of 'numpy.ndarray' objects}
#    158924    0.106    0.000    0.106    0.000 {built-in method numpy.asanyarray}
#     34931    0.093    0.000    0.759    0.000 /Users/bluez3303/Documents/GitHub/codeastro/.venv/lib/python3.13/site-packages/numpy/_core/fromnumeric.py:66(_wrapreduction)
#      9738    0.079    0.000    0.103    0.000 /Users/bluez3303/Documents/GitHub/codeastro/.venv/lib/python3.13/site-packages/numpy/_core/numeric.py:323(full)
#     29198    0.068    0.000    0.190    0.000 /Users/bluez3303/Documents/GitHub/codeastro/.venv/lib/python3.13/site-packages/numpy/_core/numerictypes.py:321(isdtype)
#     14623    0.064    0.000    0.338    0.000 /Users/bluez3303/Documents/GitHub/codeastro/.venv/lib/python3.13/site-packages/numpy/lib/_stride_tricks_impl.py:588(broadcast_arrays)
#     34064    0.062    0.000    0.093    0.000 /Users/bluez3303/Documents/GitHub/codeastro/.venv/lib/python3.13/site-packages/numpy/_core/numerictypes.py:308(_preprocess_dtype)

# %% [markdown]
# # Activities
#
# ## Activity Part 1: Analyze the output
#
# Generate the output above on your own by running `python -m cProfile -o profiler_output.txt profile_orbitize.py` and answer the following questions by analyzing the output.
#
# 1. Which function takes up the most runtime not including calls to sub-functions?
#
# 2. Which function takes up the most runtime including calls to sub-functions?
#
# 3. Which function is called the most? Which `orbitize` function is called the most?
#
# 4. If we had the magical ability to speed up one of the functions in the previous three answers by a factor of 2, which function should we speed up? What is the improvement in end-to-end runtime of the script?
#
#
# _Note: Depending on your system, some inbuilt functions might turn out to be the most time consuming ones. But here we are looking for the ones we can speed up, namely the `orbitize` functions._

# %% [markdown]
# ## Activity Part 2: Investigate why `_logl` takes so long
#
# `_logl()` is a helper function in `orbitize!` to compute the log likelihood of the data given the model. The `_logl()` function itself has a short runtime but it is calling something that takes a long time that makes it have a long `cumtime`. We can use the `print_callees()` function to look at the stats of all the functions it calls.
#
# _Hint: We can see that `compute_model` is the function with the highest cumtime, but its tottime is low, so we know something it calls takes all the time. We must dig deeper! Keep digging down recursively to find what function called within `_logl()` that takes the longest._

# %%
# Step 1:
mystats.print_callees("_logl")

# Step 2:
# Out:
#    Ordered by: internal time
#    List reduced from 10232 to 1 due to restriction <'_logl'>
#
# Function                                                                                                      called...
#                                                                                                                   ncalls  tottime  cumtime
# /Users/bluez3303/Documents/GitHub/codeastro/.venv/lib/python3.13/site-packages/orbitize/sampler.py:50(_logl)  ->    9732    0.007    0.020  /Users/bluez3303/Documents/GitHub/codeastro/.venv/lib/python3.13/site-packages/astropy/table/table.py:2102(__getitem__)
#                                                                                                                     2433    0.001    0.001  /Users/bluez3303/Documents/GitHub/codeastro/.venv/lib/python3.13/site-packages/numpy/lib/_nanfunctions_impl.py:629(_nansum_dispatcher)
#                                                                                                                     2433    0.010    0.380  /Users/bluez3303/Documents/GitHub/codeastro/.venv/lib/python3.13/site-packages/numpy/lib/_nanfunctions_impl.py:634(nansum)
#                                                                                                                     2433    4.234    4.330  /Users/bluez3303/Documents/GitHub/codeastro/.venv/lib/python3.13/site-packages/orbitize/lnlike.py:8(chi2_lnlike)
#                                                                                                                     2433    0.334   62.493  /Users/bluez3303/Documents/GitHub/codeastro/.venv/lib/python3.13/site-packages/orbitize/system.py:581(compute_model)
#                                                                                                                     4866    0.023    0.023  {built-in method numpy.array}

# %% [markdown]
# ## Activity Part 3: Which function calls `numpy.array` the most?
#
# `numpy.array` is a popular function because it gets called anytime a new numpy array gets created. We can use `print_callers()` to see which functions call it to look into potentially reducing the number of array creations to speed up the code. Which function in `orbitize` calls `numpy.array` the most times per function call (not including calls from subfunctions)?

# %%
mystats.print_callers("numpy.array")
# Out:
#    Ordered by: internal time
#    List reduced from 10232 to 2 due to restriction <'numpy.array'>
#
# Function                                                                                                                                               was called by...
#                                                                                                                                                            ncalls  tottime  cumtime
# {built-in method numpy.array}                                                                                                                          <-      77    0.000    0.000  /Users/bluez3303/Documents/GitHub/codeastro/.venv/lib/python3.13/site-packages/astropy/constants/constant.py:124(__new__)
#                                                                                                                                                                 2    0.000    0.000  /Users/bluez3303/Documents/GitHub/codeastro/.venv/lib/python3.13/site-packages/astropy/coordinates/builtin_frames/fk4_fk5_transforms.py:1(<module>)
#                                                                                                                                                                 2    0.000    0.000  /Users/bluez3303/Documents/GitHub/codeastro/.venv/lib/python3.13/site-packages/astropy/coordinates/transformations/affine.py:294(__init__)
#                                                                                                                                                                 6    0.000    0.000  /Users/bluez3303/Documents/GitHub/codeastro/.venv/lib/python3.13/site-packages/astropy/io/ascii/core.py:980(convert_numpy)
#                                                                                                                                                                21    0.000    0.000  /Users/bluez3303/Documents/GitHub/codeastro/.venv/lib/python3.13/site-packages/astropy/table/column.py:185(_convert_sequence_data_to_array)
#                                                                                                                                                                36    0.000    0.000  /Users/bluez3303/Documents/GitHub/codeastro/.venv/lib/python3.13/site-packages/astropy/table/column.py:510(__new__)
#                                                                                                                                                                 5    0.000    0.000  /Users/bluez3303/Documents/GitHub/codeastro/.venv/lib/python3.13/site-packages/astropy/time/core.py:3333(_make_array)
#                                                                                                                                                                 3    0.000    0.000  /Users/bluez3303/Documents/GitHub/codeastro/.venv/lib/python3.13/site-packages/astropy/time/formats.py:1509(__init_subclass__)
#                                                                                                                                                                 3    0.000    0.000  /Users/bluez3303/Documents/GitHub/codeastro/.venv/lib/python3.13/site-packages/astropy/time/formats.py:2175(value)
#                                                                                                                                                                10    0.000    0.000  /Users/bluez3303/Documents/GitHub/codeastro/.venv/lib/python3.13/site-packages/astropy/time/formats.py:2523(_validate_jd_for_storage)
#                                                                                                                                                             34248    0.162    0.162  /Users/bluez3303/Documents/GitHub/codeastro/.venv/lib/python3.13/site-packages/astropy/units/quantity.py:453(__new__)
#                                                                                                                                                                 2    0.000    0.000  /Users/bluez3303/Documents/GitHub/codeastro/.venv/lib/python3.13/site-packages/matplotlib/_cm_bivar.py:1(<module>)
#                                                                                                                                                                 4    0.000    0.000  /Users/bluez3303/Documents/GitHub/codeastro/.venv/lib/python3.13/site-packages/matplotlib/colors.py:607(_create_lookup_table)
#                                                                                                                                                                 1    0.000    0.000  /Users/bluez3303/Documents/GitHub/codeastro/.venv/lib/python3.13/site-packages/matplotlib/colors.py:784(_get_rgba_and_mask)
#                                                                                                                                                                 4    0.000    0.000  /Users/bluez3303/Documents/GitHub/codeastro/.venv/lib/python3.13/site-packages/matplotlib/markers.py:150(MarkerStyle)
#                                                                                                                                                                 1    0.000    0.000  /Users/bluez3303/Documents/GitHub/codeastro/.venv/lib/python3.13/site-packages/matplotlib/transforms.py:1(<module>)
#                                                                                                                                                                10    0.000    0.000  /Users/bluez3303/Documents/GitHub/codeastro/.venv/lib/python3.13/site-packages/matplotlib/tri/_triinterpolate.py:578(_ReducedHCT_Element)
#                                                                                                                                                                 1    0.000    0.000  /Users/bluez3303/Documents/GitHub/codeastro/.venv/lib/python3.13/site-packages/numpy/__init__.py:812(_mac_os_check)
#                                                                                                                                                                 3    0.000    0.000  /Users/bluez3303/Documents/GitHub/codeastro/.venv/lib/python3.13/site-packages/numpy/_core/arrayprint.py:1501(_void_scalar_to_string)
#                                                                                                                                                                32    0.000    0.000  /Users/bluez3303/Documents/GitHub/codeastro/.venv/lib/python3.13/site-packages/numpy/lib/_arraypad_impl.py:471(_as_pairs)
#                                                                                                                                                              7299    0.119    0.119  /Users/bluez3303/Documents/GitHub/codeastro/.venv/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:935(copy)
#                                                                                                                                                               126    0.000    0.000  /Users/bluez3303/Documents/GitHub/codeastro/.venv/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:5404(insert)
#                                                                                                                                                              2433    0.092    0.092  /Users/bluez3303/Documents/GitHub/codeastro/.venv/lib/python3.13/site-packages/numpy/lib/_nanfunctions_impl.py:70(_replace_nan)
#                                                                                                                                                               519    0.000    0.000  /Users/bluez3303/Documents/GitHub/codeastro/.venv/lib/python3.13/site-packages/numpy/lib/_shape_base_impl.py:607(column_stack)
#                                                                                                                                                              4866    0.015    0.015  /Users/bluez3303/Documents/GitHub/codeastro/.venv/lib/python3.13/site-packages/numpy/lib/_shape_base_impl.py:1157(tile)
#                                                                                                                                                             19467    0.004    0.004  /Users/bluez3303/Documents/GitHub/codeastro/.venv/lib/python3.13/site-packages/numpy/lib/_stride_tricks_impl.py:447(_broadcast_to)
#                                                                                                                                                             53591    0.011    0.011  /Users/bluez3303/Documents/GitHub/codeastro/.venv/lib/python3.13/site-packages/numpy/lib/_stride_tricks_impl.py:588(broadcast_arrays)
#                                                                                                                                                                 1    0.000    0.000  /Users/bluez3303/Documents/GitHub/codeastro/.venv/lib/python3.13/site-packages/numpy/ma/core.py:720(getdata)
#                                                                                                                                                                 4    0.000    0.000  /Users/bluez3303/Documents/GitHub/codeastro/.venv/lib/python3.13/site-packages/numpy/ma/core.py:2882(__new__)
#                                                                                                                                                                 4    0.000    0.000  /Users/bluez3303/Documents/GitHub/codeastro/.venv/lib/python3.13/site-packages/numpy/ma/core.py:6751(__new__)
#                                                                                                                                                                 4    0.000    0.000  /Users/bluez3303/Documents/GitHub/codeastro/.venv/lib/python3.13/site-packages/numpy/polynomial/chebyshev.py:1(<module>)
#                                                                                                                                                                 2    0.000    0.000  /Users/bluez3303/Documents/GitHub/codeastro/.venv/lib/python3.13/site-packages/numpy/polynomial/chebyshev.py:1970(Chebyshev)
#                                                                                                                                                                 4    0.000    0.000  /Users/bluez3303/Documents/GitHub/codeastro/.venv/lib/python3.13/site-packages/numpy/polynomial/hermite.py:1(<module>)
#                                                                                                                                                                 2    0.000    0.000  /Users/bluez3303/Documents/GitHub/codeastro/.venv/lib/python3.13/site-packages/numpy/polynomial/hermite.py:1751(Hermite)
#                                                                                                                                                                 4    0.000    0.000  /Users/bluez3303/Documents/GitHub/codeastro/.venv/lib/python3.13/site-packages/numpy/polynomial/hermite_e.py:1(<module>)
#                                                                                                                                                                 2    0.000    0.000  /Users/bluez3303/Documents/GitHub/codeastro/.venv/lib/python3.13/site-packages/numpy/polynomial/hermite_e.py:1649(HermiteE)
#                                                                                                                                                                 4    0.000    0.000  /Users/bluez3303/Documents/GitHub/codeastro/.venv/lib/python3.13/site-packages/numpy/polynomial/laguerre.py:1(<module>)
#                                                                                                                                                                 2    0.000    0.000  /Users/bluez3303/Documents/GitHub/codeastro/.venv/lib/python3.13/site-packages/numpy/polynomial/laguerre.py:1686(Laguerre)
#                                                                                                                                                                 4    0.000    0.000  /Users/bluez3303/Documents/GitHub/codeastro/.venv/lib/python3.13/site-packages/numpy/polynomial/legendre.py:1(<module>)
#                                                                                                                                                                 2    0.000    0.000  /Users/bluez3303/Documents/GitHub/codeastro/.venv/lib/python3.13/site-packages/numpy/polynomial/legendre.py:1612(Legendre)
#                                                                                                                                                                 4    0.000    0.000  /Users/bluez3303/Documents/GitHub/codeastro/.venv/lib/python3.13/site-packages/numpy/polynomial/polynomial.py:1(<module>)
#                                                                                                                                                                 2    0.000    0.000  /Users/bluez3303/Documents/GitHub/codeastro/.venv/lib/python3.13/site-packages/numpy/polynomial/polynomial.py:1615(Polynomial)
#                                                                                                                                                              2433    0.004    0.004  /Users/bluez3303/Documents/GitHub/codeastro/.venv/lib/python3.13/site-packages/orbitize/kepler.py:48(calc_orbit)
#                                                                                                                                                              4866    0.023    0.023  /Users/bluez3303/Documents/GitHub/codeastro/.venv/lib/python3.13/site-packages/orbitize/sampler.py:50(_logl)
#                                                                                                                                                                 3    0.000    0.000  /Users/bluez3303/Documents/GitHub/codeastro/.venv/lib/python3.13/site-packages/orbitize/sampler.py:169(__init__)
#                                                                                                                                                              7299    0.012    0.012  /Users/bluez3303/Documents/GitHub/codeastro/.venv/lib/python3.13/site-packages/orbitize/sampler.py:412(reject)
#                                                                                                                                                                 1    0.000    0.000  /Users/bluez3303/Documents/GitHub/codeastro/.venv/lib/python3.13/site-packages/orbitize/sampler.py:529(run_sampler)
#                                                                                                                                                              4874    0.065    0.065  /Users/bluez3303/Documents/GitHub/codeastro/.venv/lib/python3.13/site-packages/scipy/_external/array_api_compat/numpy/_aliases.py:70(asarray)
#                                                                                                                                                                 1    0.000    0.000  /Users/bluez3303/Documents/GitHub/codeastro/.venv/lib/python3.13/site-packages/scipy/integrate/_ivp/dop853_coefficients.py:1(<module>)
#                                                                                                                                                                 5    0.000    0.000  /Users/bluez3303/Documents/GitHub/codeastro/.venv/lib/python3.13/site-packages/scipy/integrate/_ivp/radau.py:1(<module>)
#                                                                                                                                                                 5    0.000    0.000  /Users/bluez3303/Documents/GitHub/codeastro/.venv/lib/python3.13/site-packages/scipy/integrate/_ivp/rk.py:183(RK23)
#                                                                                                                                                                 5    0.000    0.000  /Users/bluez3303/Documents/GitHub/codeastro/.venv/lib/python3.13/site-packages/scipy/integrate/_ivp/rk.py:374(RK45)
#                                                                                                                                                                11    0.000    0.000  /Users/bluez3303/Documents/GitHub/codeastro/.venv/lib/python3.13/site-packages/scipy/interpolate/_fitpack_impl.py:1(<module>)
#                                                                                                                                                                 2    0.000    0.000  /Users/bluez3303/Documents/GitHub/codeastro/.venv/lib/python3.13/site-packages/scipy/interpolate/_interpolate.py:298(__init__)
#                                                                                                                                                                 2    0.000    0.000  /Users/bluez3303/Documents/GitHub/codeastro/.venv/lib/python3.13/site-packages/scipy/stats/_levy_stable/__init__.py:1(<module>)
#                                                                                                                                                                 5    0.000    0.000  /Users/bluez3303/Documents/GitHub/codeastro/.venv/lib/python3.13/site-packages/scipy/stats/_morestats.py:1(<module>)
# /Users/bluez3303/Documents/GitHub/codeastro/.venv/lib/python3.13/site-packages/scipy/_external/array_api_compat/common/_helpers.py:95(is_numpy_array)  <-    4866    0.009    0.016  /Users/bluez3303/Documents/GitHub/codeastro/.venv/lib/python3.13/site-packages/scipy/_external/array_api_compat/common/_helpers.py:722(device)

# %% [markdown]
# # Code Optimizing Strategy
#
# <div style="text-align: center">
#   <img src="imgs/code_speedup.png" width="600">
# </div>
#
# - Generally, it is important to **focus on the 1 or 2 slowest functions**. Speeding up something that takes 50% of the runtime by 2x gives you a 25% overall speedup. But if the function takes only 10%, the same 2x improvement gives just a 5% gain.
#
# - For all else, it is generally more important to optimize code readibility over runtime. Code that is more readible is less prone to bugs and easier to maintain. If a piece of code takes only 0.0001% of the runtime, any amount of speed up is not worth making the code hard to read (from a person-hour perspective). Many times, it is difficult to gain more than a factor of 2 speed up in runtime. __Definitely think about the potential gain in speed-up versus how long it takes to write and maintain the code__.

# %% [markdown]
# # Some Ways to Speed Up Your Code
#
# There's unfortunately not one single method to speed up your code. Once you have identified the critical chunk of code to speed up, here are a few ideas to try:
#
# Level 1:
# - Eliminate computations that are not being used (e.g., computing variables you do not use; processing parts of images that will be discarded).
# - Use `numpy` functions whenever possible for matrix operations
# - Avoid copying variables when they do not need to be copied (e.g., if the input is already a numpy.array, you don't need to wrap it with `np.array()` to ensure it's a numpy array).
# - Avoid using python `for` and `while` loops (see example below)
#
# Level 2:
# - If MKL/BLAS is being run inside of already-parallelized code, disable MKL/BLAS (see Day 2 parallelization materials for more details on MKL/BLAS).
# - Reduce the number of iterations or increase the tolerance of routines that are unnecessarily precise (e.g., optimizers can run for less iterations; sin and cos can be approximated by taylor expansions).
#
# Level 3:
# - Turn some of your python code into C-code and call it with Python

# %%
"""
Here's an example of replacing a for loop with a faster masked operation.
This is called VECTORIZATION.
"""

import numpy as np

# add 5 to each value in a list that's greater than 6
arr_1 = np.asarray([1, 4, 6, 7, 8, 10, 2])
arr_2 = np.asarray([1, 4, 6, 7, 8, 10, 2])


# first option (much slower for long arrays)
for i, elem in enumerate(arr_1):
    if elem > 6:
        arr_1[i] += 5

# second option (faster)
mask_arr = arr_2 > 6
arr_2[mask_arr] += 5

# print resulting arrays for both cases
print(arr_1)
print(arr_2)

"""
Extra Activity: Time these two methods to see the difference in speed. Use the `time` module.
"""

# %% [markdown]
# ## Extra Reading: Code Performance Extrapolation
#
# If your code takes 24 hours to run to completion, or needs to be run on a cluster, it is likely still easier to develop and benchmark it on your laptop. We can use extrapolation to estimate performance.
#
# ### Runtime
#
# Generally algorithm runtimes scale as N^a where a is some positive number greater than 1, and N is the size of your data. (In CS terms, this is often discussed in "Big O" notation as  $O(N^a)$ runtime). If your data is too big or takes too long to benchmark on a single machine, try running your code on much smaller data. If you do this for ~3-5 different test data with different N, you can estimate what is the scaling of your code (i.e., what is "a"). Once you know the scaling you can use that scaling relation to extrapolate how long it will take on larger datasets. If you can also use more cores, you can divide the final runtime by the number of cores you can use.
#
# For example (very idealized), my code takes 1 second on 10x10 data, 100 seconds on 100x100 data, and 400 seconds on 200x200 data (all on a single core). My code scales as (N/10)^2 where N is the size of one dimension of the data. If I want to run it on 10000x10000 data with 100 cores, my code should take (1000^2)/100 = 10,000 seconds to run. In practice there will probably be some deviations to these estimates (due to overheads, CPU usage scheudling, other factors), but this scaling should give you a general sense of how long something will take.
#
# ### Memory
#
# If you are worried that your program will run out of memory, try calculating how much memory your program uses. On modern 64-bit machines, a single number (an integer, float) takes up 8 bytes. If you have an array of 1000x1000 floats, then it will take up 8e6 bytes or 8 MBs. If you have 3-D numerical data with dimensions 1000x1000x1000, then it will take up 8e9 bytes or 8 GBs.
